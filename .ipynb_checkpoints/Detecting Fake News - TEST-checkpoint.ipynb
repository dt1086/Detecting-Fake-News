# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import requests

import nltk
from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import re

np.random.seed(7)

# %%
df_politifact = pd.read_csv('data/politifact_phase2_raw_2018_7_3.csv', error_bad_lines=False)
df_snopes = pd.read_csv('data/snopes_phase2_raw_2018_7_3.csv', error_bad_lines=False)
# Out:
# b'Skipping line 23797: expected 16 fields, saw 18\n'

# %%
df_politifact
# Out:
#                                    politifact_url_phase1 fact_tag_phase1  \
# 0      http://www.politifact.com/punditfact/statement...     Mostly True
# 1      http://www.politifact.com/punditfact/statement...     Mostly True
# 2      http://www.politifact.com/punditfact/statement...     Mostly True
# 3      http://www.politifact.com/punditfact/statement...     Mostly True
# 4      http://www.politifact.com/punditfact/statement...     Mostly True
# ...                                                  ...             ...
# 50627  http://www.politifact.com/truth-o-meter/statem...            True
# 50628  http://www.politifact.com/truth-o-meter/statem...            True
# 50629  http://www.politifact.com/truth-o-meter/statem...           False
# 50630  http://www.politifact.com/truth-o-meter/statem...     Mostly True
# 50631  http://www.politifact.com/truth-o-meter/statem...            True
#
#                                     article_title_phase1  \
# 0      Story says poll shows Trump tied to Obama at s...
# 1      Story says poll shows Trump tied to Obama at s...
# 2      Story says poll shows Trump tied to Obama at s...
# 3      Story says poll shows Trump tied to Obama at s...
# 4      Story says poll shows Trump tied to Obama at s...
# ...                                                  ...
# 50627              An accurate summary of economic stats
# 50628                A fair account of Romney's position
# 50629           Most scientists say humans cause warming
# 50630        Correct, but stats came from friendly group
# 50631                    He was credited as a "tinkerer"
#
#                                     article_claim_phase1  \
# 0      "Trump approval rating better than Obama and R...
# 1      "Trump approval rating better than Obama and R...
# 2      "Trump approval rating better than Obama and R...
# 3      "Trump approval rating better than Obama and R...
# 4      "Trump approval rating better than Obama and R...
# ...                                                  ...
# 50627  "Corporate profits are up, CEO pay is up, but ...
# 50628  "I'm for a three-state political solution in I...
# 50629  "For every single scientist that tells you (gl...
# 50630  "New Mexico was 46th in teacher pay (when he w...
# 50631  "Tommy Thompson created the first school choic...
#
#                            article_claim_citation_phase1  \
# 0      — The Gateway Pundit on Saturday, June 9th, 20...
# 1      — The Gateway Pundit on Saturday, June 9th, 20...
# 2      — The Gateway Pundit on Saturday, June 9th, 20...
# 3      — The Gateway Pundit on Saturday, June 9th, 20...
# 4      — The Gateway Pundit on Saturday, June 9th, 20...
# ...                                                  ...
# 50627  — Hillary Clinton on Sunday, July 22nd, 2007 i...
# 50628       — Sam Brownback on Friday, June 8th, 2007 in
# 50629  — Tom Tancredo on Tuesday, May 15th, 2007 in C...
# 50630  — Bill Richardson on Thursday, May 10th, 2007 ...
# 50631  — Tommy Thompson on Tuesday, May 1st, 2007 in ...
#
#                    article_published_date_phase1 article_researched_by_phase1  \
# 0           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# 1           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# 2           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# 3           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# 4           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# ...                                          ...                          ...
# 50627  Wednesday, August 1st, 2007 at 12:00 a.m.                  Caryn Baird
# 50628     Tuesday, July 10th, 2007 at 12:00 a.m.                  Nell Benton
# 50629     Tuesday, June 12th, 2007 at 12:00 a.m.                   Bill Adair
# 50630     Tuesday, June 12th, 2007 at 12:00 a.m.                 Lea Iadarola
# 50631     Wednesday, May 2nd, 2007 at 12:00 a.m.                   Bill Adair
#
#       article_edited_by_phase1            article_categories_phase1  \
# 0                Katie Sanders  Fake news, Polls and Public Opinion
# 1                Katie Sanders  Fake news, Polls and Public Opinion
# 2                Katie Sanders  Fake news, Polls and Public Opinion
# 3                Katie Sanders  Fake news, Polls and Public Opinion
# 4                Katie Sanders  Fake news, Polls and Public Opinion
# ...                        ...                                  ...
# 50627         Scott Montgomery                              Economy
# 50628               Bill Adair                                 Iraq
# 50629         Scott Montgomery          Climate Change, Environment
# 50630         Scott Montgomery                            Education
# 50631               Bill Adair                            Education
#
#                                      original_url_phase1  \
# 0      http://www.foxnews.com/politics/interactive/20...
# 1      http://www.foxnews.com/politics/2018/06/08/tru...
# 2      http://www.rasmussenreports.com/public_content...
# 3      https://dyn.realclearpolitics.com/epolls/other...
# 4      https://www.nbcnews.com/politics/first-read/po...
# ...                                                  ...
# 50627  http://www.forbes.com/2007/05/03/highest-paid-...
# 50628  http://www.foreignaffairs.org/20070701faessay8...
# 50629                                http://www.ipcc.ch/
# 50630         http://www.nea.org/edstats/RankFull06b.htm
# 50631  http://www.allianceforschoolchoice.org/school_...
#
#        page_is_first_citation_phase1  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 50627                          False
# 50628                           True
# 50629                           True
# 50630                           True
# 50631                           True
#
#                                             error_phase2  \
# 0                                         Resource moved
# 1                                               No Error
# 2                                         Resource moved
# 3                                           Website down
# 4                                               No Error
# ...                                                  ...
# 50627  404 Client Error: Not Found for url: https://w...
# 50628  502 Server Error: BAD_GATEWAY for url: https:/...
# 50629                                           No Error
# 50630  404 Client Error: Not Found for url: http://ww...
# 50631  404 Client Error: Not Found for url: http://ww...
#
#                             original_article_text_phase2  \
# 0                                                     --
# 1      The bleak presidential portrait painted by the...
# 2                                                     --
# 3                                                     --
# 4      Breaking News Emails Get breaking news alerts ...
# ...                                                  ...
# 50627                                                 --
# 50628                                                 --
# 50629  At the 43rd Session of the IPCC in April 2016,...
# 50630                                                 --
# 50631                                                 --
#
#                                     article_title_phase2 publish_date_phase2  \
# 0                                                    NaN                 NaN
# 1      A Trump jump in the polls despite the media's ...          2018-06-08
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4      NBC News/WSJ poll: Economic satisfaction under...                 NaN
# ...                                                  ...                 ...
# 50627                                                NaN                 NaN
# 50628                                                NaN                 NaN
# 50629          Intergovernmental Panel on Climate Change                 NaN
# 50630                                                NaN                 NaN
# 50631                                                NaN                 NaN
#
#       author_phase2
# 0               NaN
# 1      Howard Kurtz
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 50627           NaN
# 50628           NaN
# 50629           NaN
# 50630           NaN
# 50631           NaN
#
# [50632 rows x 16 columns]

# %%
df_politifact['fact_tag_phase1'].value_counts()
# Out:
# Half-True         10148
# False              9478
# Mostly False       9169
# Mostly True        9139
# True               6279
# Pants on Fire!     5609
# Full Flop           488
# Half Flip           218
# No Flip             104
# Name: fact_tag_phase1, dtype: int64

# %%
drop_list = ['Full Flop', 'Half Flip', 'No Flip', 'Half-True']

for k in drop_list:
    df_politifact = df_politifact[df_politifact['fact_tag_phase1'] != k]
df_politifact
# Out:
#                                    politifact_url_phase1 fact_tag_phase1  \
# 0      http://www.politifact.com/punditfact/statement...     Mostly True
# 1      http://www.politifact.com/punditfact/statement...     Mostly True
# 2      http://www.politifact.com/punditfact/statement...     Mostly True
# 3      http://www.politifact.com/punditfact/statement...     Mostly True
# 4      http://www.politifact.com/punditfact/statement...     Mostly True
# ...                                                  ...             ...
# 50627  http://www.politifact.com/truth-o-meter/statem...            True
# 50628  http://www.politifact.com/truth-o-meter/statem...            True
# 50629  http://www.politifact.com/truth-o-meter/statem...           False
# 50630  http://www.politifact.com/truth-o-meter/statem...     Mostly True
# 50631  http://www.politifact.com/truth-o-meter/statem...            True
#
#                                     article_title_phase1  \
# 0      Story says poll shows Trump tied to Obama at s...
# 1      Story says poll shows Trump tied to Obama at s...
# 2      Story says poll shows Trump tied to Obama at s...
# 3      Story says poll shows Trump tied to Obama at s...
# 4      Story says poll shows Trump tied to Obama at s...
# ...                                                  ...
# 50627              An accurate summary of economic stats
# 50628                A fair account of Romney's position
# 50629           Most scientists say humans cause warming
# 50630        Correct, but stats came from friendly group
# 50631                    He was credited as a "tinkerer"
#
#                                     article_claim_phase1  \
# 0      "Trump approval rating better than Obama and R...
# 1      "Trump approval rating better than Obama and R...
# 2      "Trump approval rating better than Obama and R...
# 3      "Trump approval rating better than Obama and R...
# 4      "Trump approval rating better than Obama and R...
# ...                                                  ...
# 50627  "Corporate profits are up, CEO pay is up, but ...
# 50628  "I'm for a three-state political solution in I...
# 50629  "For every single scientist that tells you (gl...
# 50630  "New Mexico was 46th in teacher pay (when he w...
# 50631  "Tommy Thompson created the first school choic...
#
#                            article_claim_citation_phase1  \
# 0      — The Gateway Pundit on Saturday, June 9th, 20...
# 1      — The Gateway Pundit on Saturday, June 9th, 20...
# 2      — The Gateway Pundit on Saturday, June 9th, 20...
# 3      — The Gateway Pundit on Saturday, June 9th, 20...
# 4      — The Gateway Pundit on Saturday, June 9th, 20...
# ...                                                  ...
# 50627  — Hillary Clinton on Sunday, July 22nd, 2007 i...
# 50628       — Sam Brownback on Friday, June 8th, 2007 in
# 50629  — Tom Tancredo on Tuesday, May 15th, 2007 in C...
# 50630  — Bill Richardson on Thursday, May 10th, 2007 ...
# 50631  — Tommy Thompson on Tuesday, May 1st, 2007 in ...
#
#                    article_published_date_phase1 article_researched_by_phase1  \
# 0           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# 1           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# 2           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# 3           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# 4           Monday, June 18th, 2018 at 9:00 a.m.                  Amy Sherman
# ...                                          ...                          ...
# 50627  Wednesday, August 1st, 2007 at 12:00 a.m.                  Caryn Baird
# 50628     Tuesday, July 10th, 2007 at 12:00 a.m.                  Nell Benton
# 50629     Tuesday, June 12th, 2007 at 12:00 a.m.                   Bill Adair
# 50630     Tuesday, June 12th, 2007 at 12:00 a.m.                 Lea Iadarola
# 50631     Wednesday, May 2nd, 2007 at 12:00 a.m.                   Bill Adair
#
#       article_edited_by_phase1            article_categories_phase1  \
# 0                Katie Sanders  Fake news, Polls and Public Opinion
# 1                Katie Sanders  Fake news, Polls and Public Opinion
# 2                Katie Sanders  Fake news, Polls and Public Opinion
# 3                Katie Sanders  Fake news, Polls and Public Opinion
# 4                Katie Sanders  Fake news, Polls and Public Opinion
# ...                        ...                                  ...
# 50627         Scott Montgomery                              Economy
# 50628               Bill Adair                                 Iraq
# 50629         Scott Montgomery          Climate Change, Environment
# 50630         Scott Montgomery                            Education
# 50631               Bill Adair                            Education
#
#                                      original_url_phase1  \
# 0      http://www.foxnews.com/politics/interactive/20...
# 1      http://www.foxnews.com/politics/2018/06/08/tru...
# 2      http://www.rasmussenreports.com/public_content...
# 3      https://dyn.realclearpolitics.com/epolls/other...
# 4      https://www.nbcnews.com/politics/first-read/po...
# ...                                                  ...
# 50627  http://www.forbes.com/2007/05/03/highest-paid-...
# 50628  http://www.foreignaffairs.org/20070701faessay8...
# 50629                                http://www.ipcc.ch/
# 50630         http://www.nea.org/edstats/RankFull06b.htm
# 50631  http://www.allianceforschoolchoice.org/school_...
#
#        page_is_first_citation_phase1  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 50627                          False
# 50628                           True
# 50629                           True
# 50630                           True
# 50631                           True
#
#                                             error_phase2  \
# 0                                         Resource moved
# 1                                               No Error
# 2                                         Resource moved
# 3                                           Website down
# 4                                               No Error
# ...                                                  ...
# 50627  404 Client Error: Not Found for url: https://w...
# 50628  502 Server Error: BAD_GATEWAY for url: https:/...
# 50629                                           No Error
# 50630  404 Client Error: Not Found for url: http://ww...
# 50631  404 Client Error: Not Found for url: http://ww...
#
#                             original_article_text_phase2  \
# 0                                                     --
# 1      The bleak presidential portrait painted by the...
# 2                                                     --
# 3                                                     --
# 4      Breaking News Emails Get breaking news alerts ...
# ...                                                  ...
# 50627                                                 --
# 50628                                                 --
# 50629  At the 43rd Session of the IPCC in April 2016,...
# 50630                                                 --
# 50631                                                 --
#
#                                     article_title_phase2 publish_date_phase2  \
# 0                                                    NaN                 NaN
# 1      A Trump jump in the polls despite the media's ...          2018-06-08
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4      NBC News/WSJ poll: Economic satisfaction under...                 NaN
# ...                                                  ...                 ...
# 50627                                                NaN                 NaN
# 50628                                                NaN                 NaN
# 50629          Intergovernmental Panel on Climate Change                 NaN
# 50630                                                NaN                 NaN
# 50631                                                NaN                 NaN
#
#       author_phase2
# 0               NaN
# 1      Howard Kurtz
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 50627           NaN
# 50628           NaN
# 50629           NaN
# 50630           NaN
# 50631           NaN
#
# [39674 rows x 16 columns]

# %%
df_politifact['fact_tag_phase1'].value_counts()
# Out:
# False             9478
# Mostly False      9169
# Mostly True       9139
# True              6279
# Pants on Fire!    5609
# Name: fact_tag_phase1, dtype: int64

# %%
df_politifact['article_title_phase1'][0]
# Out:
# 'Story says poll shows Trump tied to Obama at same point in presidency'

# %%
df_snopes
# Out:
#       fact_rating_phase1                                  snopes_url_phase1  \
# 0                   true  https://www.snopes.com/fact-check/lori-mcallen...
# 1                   true  https://www.snopes.com/fact-check/is-trump-adm...
# 2                   true  https://www.snopes.com/fact-check/is-trump-adm...
# 3                   true  https://www.snopes.com/fact-check/is-trump-adm...
# 4                   true  https://www.snopes.com/fact-check/is-trump-adm...
# ...                  ...                                                ...
# 20770             legend  https://www.snopes.com/fact-check/faces-in-the...
# 20771             legend  https://www.snopes.com/fact-check/faces-in-the...
# 20772             legend      https://www.snopes.com/fact-check/ice-badges/
# 20773             legend  https://www.snopes.com/fact-check/c3p0-trading...
# 20774             legend  https://www.snopes.com/fact-check/c3p0-trading...
#
#                                     article_title_phase1  \
# 0      Did an Oregon Department of Transportation Emp...
# 1      Is the Trump Administration Paying Southwest K...
# 2      Is the Trump Administration Paying Southwest K...
# 3      Is the Trump Administration Paying Southwest K...
# 4      Is the Trump Administration Paying Southwest K...
# ...                                                  ...
# 20770                                 Faces in the Cloud
# 20771                                 Faces in the Cloud
# 20772                                         ICE Badges
# 20773              Risqué ‘Star Wars’ C-3P0 Trading Card
# 20774              Risqué ‘Star Wars’ C-3P0 Trading Card
#
#                 article_category_phase1 article_date_phase1  \
# 0      Viral Phenomena  Viral Phenomena        21 June 2018
# 1                    Politics  Politics        22 June 2018
# 2                    Politics  Politics        22 June 2018
# 3                    Politics  Politics        22 June 2018
# 4                    Politics  Politics        22 June 2018
# ...                                 ...                 ...
# 20770                    September 11th   21 September 2001
# 20771                    September 11th   21 September 2001
# 20772    Inboxer Rebellion  Immigration         24 May 2006
# 20773    Entertainment  Risqué Business      16 August 2007
# 20774    Entertainment  Risqué Business      16 August 2007
#
#                                     article_claim_phase1  \
# 0      In June 2018, Oregon DOT employee Lori McAllen...
# 1      The Trump administration is paying Southwest K...
# 2      The Trump administration is paying Southwest K...
# 3      The Trump administration is paying Southwest K...
# 4      The Trump administration is paying Southwest K...
# ...                                                  ...
# 20770  Images of the World Trade Center fire reveal t...
# 20771  Images of the World Trade Center fire reveal t...
# 20772  E-mail describes ruse intended to scare away l...
# 20773  A Star Wars trading card was altered to depict...
# 20774  A Star Wars trading card was altered to depict...
#
#                                article_origin_url_phase1  \
# 0                                http://archive.is/HpML7
# 1      https://www.dallasnews.com/news/immigration/20...
# 2      https://www.bloomberg.com/news/articles/2018-0...
# 3      https://www.bloomberg.com/news/articles/2018-0...
# 4      https://web.archive.org/web/20180604042055/htt...
# ...                                                  ...
# 20770                       http://www.markdphillips.com
# 20771               http://www.skepdic.com/pareidol.html
# 20772                                http://www.ice.gov/
# 20773                           http://www.starwars.com/
# 20774  https://web.archive.org/web/20051013055316/htt...
#
#        index_paragraph_phase1  page_is_first_citation_phase1 error_phase2  \
# 0                           2                          False     No Error
# 1                           1                           True     No Error
# 2                           1                          False     No Error
# 3                           6                          False     No Error
# 4                          10                          False     No Error
# ...                       ...                            ...          ...
# 20770                       1                           True     No Error
# 20771                       7                          False     No Error
# 20772                       2                          False     No Error
# 20773                       3                          False     No Error
# 20774                       5                          False     No Error
#
#                             original_article_text_phase2  \
# 0      Reddit Voat Twitter VKontakte Pinboard Livejou...
# 1      A Southwest Key spokeswoman, Cindy Casares, ha...
# 2      The Trump administration plans to pay a Texas ...
# 3      The Trump administration plans to pay a Texas ...
# 4      Who We Are Southwest Key Programs is a private...
# ...                                                  ...
# 20770  The best skiers in the world came to the East ...
# 20771  pareidolia There is an universal tendency amon...
# 20772  If your school’s SEVP certification has been w...
# 20773  Imperial medics tend to soldiers on the battle...
# 20774  Topps - US - Star Wars Series 4 (Green Border)...
#
#                                     article_title_phase2 publish_date_phase2  \
# 0        She works for ODOT/DMV...Let's make her famous.          2018-06-21
# 1      Texas nonprofit has received $1.5 billion in f...          2018-06-19
# 2      Trump’s Immigrant Child Detentions Mean $458 M...          2018-06-19
# 3      Trump’s Immigrant Child Detentions Mean $458 M...          2018-06-19
# 4                     Who We Are: Southwest Key Programs                 NaN
# ...                                                  ...                 ...
# 20770                      Photography of the real world                 NaN
# 20771                           the Skeptic's Dictionary                 NaN
# 20772                                                ICE                 NaN
# 20773                     The Official Star Wars Website                 NaN
# 20774  Star Wars Trading Cards :: 1977 Topps Star War...                 NaN
#
#                  author_phase2
# 0                          NaN
# 1               Jennifer Emily
# 2                   Alex Wayne
# 3                   Alex Wayne
# 4                          NaN
# ...                        ...
# 20770                      NaN
# 20771                      NaN
# 20772                      NaN
# 20773      Check Out New Books
# 20774  Star Wars Trading Cards
#
# [20775 rows x 14 columns]

# %%
df_snopes['fact_rating_phase1'].value_counts()
# Out:
# false                  11247
# mixture                 2595
# mostly false            2020
# true                    1903
# unproven                1737
# mostly true              664
# miscaptioned             302
# outdated                 106
# misattributed             58
# scam                      53
# legend                    49
# correct attribution       41
# Name: fact_rating_phase1, dtype: int64

# %% [markdown]
# ### Final Data Sources

# %%
df_KaggleTrain = pd.read_csv('data/KaggleTrain.csv')

# %%
#1: unreliable
#0: reliable
df_KaggleTrain
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# 2                             Consortiumnews.com
# 3                                Jessica Purkiss
# 4                                 Howard Portnoy
# ...                                          ...
# 20795                              Jerome Hudson
# 20796                           Benjamin Hoffman
# 20797  Michael J. de la Merced and Rachel Abrams
# 20798                                Alex Ansary
# 20799                              David Swanson
#
#                                                     text  label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1      Ever get the feeling your life circles the rou...      0
# 2      Why the Truth Might Get You Fired October 29, ...      1
# 3      Videos 15 Civilians Killed In Single US Airstr...      1
# 4      Print \nAn Iranian woman has been sentenced to...      1
# ...                                                  ...    ...
# 20795  Rapper T. I. unloaded on black celebrities who...      0
# 20796  When the Green Bay Packers lost to the Washing...      0
# 20797  The Macy’s of today grew from the union of sev...      0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...      1
# 20799    David Swanson is an author, activist, journa...      1
#
# [20800 rows x 5 columns]

# %%
df_KaggleTrain.drop(['author', 'id'], axis=1, inplace=True)
df_KaggleTrain
# Out:
#                                                    title  \
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...
# 1      FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                      Why the Truth Might Get You Fired
# 3      15 Civilians Killed In Single US Airstrike Hav...
# 4      Iranian woman jailed for fictional unpublished...
# ...                                                  ...
# 20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799                          What Keeps the F-35 Alive
#
#                                                     text  label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1      Ever get the feeling your life circles the rou...      0
# 2      Why the Truth Might Get You Fired October 29, ...      1
# 3      Videos 15 Civilians Killed In Single US Airstr...      1
# 4      Print \nAn Iranian woman has been sentenced to...      1
# ...                                                  ...    ...
# 20795  Rapper T. I. unloaded on black celebrities who...      0
# 20796  When the Green Bay Packers lost to the Washing...      0
# 20797  The Macy’s of today grew from the union of sev...      0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...      1
# 20799    David Swanson is an author, activist, journa...      1
#
# [20800 rows x 3 columns]

# %%
df_DataFlair = pd.read_csv('data/DataFlairnews.csv')

# %%
df_DataFlair
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4     It's primary day in New York and front-runners...  REAL
# ...                                                 ...   ...
# 6330  The State Department told the Republican Natio...  REAL
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 6332   Anti-Trump Protesters Are Tools of the Oligar...  FAKE
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...  REAL
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL
#
# [6335 rows x 4 columns]

# %%
df_DataFlair['label'].value_counts()
# Out:
# REAL    3171
# FAKE    3164
# Name: label, dtype: int64

# %%
df_DataFlair.text[0]
# Out:
# 'Daniel Greenfield, a Shillman Journalism Fellow at the Freedom Center, is a New York writer focusing on radical Islam. \nIn the final stretch of the election, Hillary Rodham Clinton has gone to war with the FBI. \nThe word “unprecedented” has been thrown around so often this election that it ought to be retired. But it’s still unprecedented for the nominee of a major political party to go war with the FBI. \nBut that’s exactly what Hillary and her people have done. Coma patients just waking up now and watching an hour of CNN from their hospital beds would assume that FBI Director James Comey is Hillary’s opponent in this election. \nThe FBI is under attack by everyone from Obama to CNN. Hillary’s people have circulated a letter attacking Comey. There are currently more media hit pieces lambasting him than targeting Trump. It wouldn’t be too surprising if the Clintons or their allies were to start running attack ads against the FBI. \nThe FBI’s leadership is being warned that the entire left-wing establishment will form a lynch mob if they continue going after Hillary. And the FBI’s credibility is being attacked by the media and the Democrats to preemptively head off the results of the investigation of the Clinton Foundation and Hillary Clinton. \nThe covert struggle between FBI agents and Obama’s DOJ people has gone explosively public. \nThe New York Times has compared Comey to J. Edgar Hoover. Its bizarre headline, “James Comey Role Recalls Hoover’s FBI, Fairly or Not” practically admits up front that it’s spouting nonsense. The Boston Globe has published a column calling for Comey’s resignation. Not to be outdone, Time has an editorial claiming that the scandal is really an attack on all women. \nJames Carville appeared on MSNBC to remind everyone that he was still alive and insane. He accused Comey of coordinating with House Republicans and the KGB. And you thought the “vast right wing conspiracy” was a stretch. \nCountless media stories charge Comey with violating procedure. Do you know what’s a procedural violation? Emailing classified information stored on your bathroom server. \nSenator Harry Reid has sent Comey a letter accusing him of violating the Hatch Act. The Hatch Act is a nice idea that has as much relevance in the age of Obama as the Tenth Amendment. But the cable news spectrum quickly filled with media hacks glancing at the Wikipedia article on the Hatch Act under the table while accusing the FBI director of one of the most awkward conspiracies against Hillary ever. \nIf James Comey is really out to hurt Hillary, he picked one hell of a strange way to do it. \nNot too long ago Democrats were breathing a sigh of relief when he gave Hillary Clinton a pass in a prominent public statement. If he really were out to elect Trump by keeping the email scandal going, why did he trash the investigation? Was he on the payroll of House Republicans and the KGB back then and playing it coy or was it a sudden development where Vladimir Putin and Paul Ryan talked him into taking a look at Anthony Weiner’s computer? \nEither Comey is the most cunning FBI director that ever lived or he’s just awkwardly trying to navigate a political mess that has trapped him between a DOJ leadership whose political futures are tied to Hillary’s victory and his own bureau whose apolitical agents just want to be allowed to do their jobs. \nThe only truly mysterious thing is why Hillary and her associates decided to go to war with a respected Federal agency. Most Americans like the FBI while Hillary Clinton enjoys a 60% unfavorable rating. \nAnd it’s an interesting question. \nHillary’s old strategy was to lie and deny that the FBI even had a criminal investigation underway. Instead her associates insisted that it was a security review. The FBI corrected her and she shrugged it off. But the old breezy denial approach has given way to a savage assault on the FBI. \nPretending that nothing was wrong was a bad strategy, but it was a better one that p ...

# %%
df_DataFlair.drop('Unnamed: 0', axis=1, inplace=True)
df_DataFlair
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 2           Kerry to go to Paris in gesture of sympathy
# 3     Bernie supporters on Twitter erupt in anger ag...
# 4      The Battle of New York: Why This Primary Matters
# ...                                                 ...
# 6330  State Department says it can't find emails fro...
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333  In Ethiopia, Obama seeks progress on peace, se...
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4     It's primary day in New York and front-runners...  REAL
# ...                                                 ...   ...
# 6330  The State Department told the Republican Natio...  REAL
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 6332   Anti-Trump Protesters Are Tools of the Oligar...  FAKE
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...  REAL
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL
#
# [6335 rows x 3 columns]

# %%
df_ISOT_true = pd.read_csv('data/ISOTTrue.csv')
df_ISOT_false = pd.read_csv('data/ISOTFake.csv')

# %%
df_ISOT_false
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# 2      On Friday, it was revealed that former Milwauk...         News
# 3      On Christmas day, Donald Trump announced that ...         News
# 4      Pope Francis used his annual Christmas Day mes...         News
# ...                                                  ...          ...
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                     date
# 0      December 31, 2017
# 1      December 31, 2017
# 2      December 30, 2017
# 3      December 29, 2017
# 4      December 25, 2017
# ...                  ...
# 23476   January 16, 2016
# 23477   January 16, 2016
# 23478   January 15, 2016
# 23479   January 14, 2016
# 23480   January 12, 2016
#
# [23481 rows x 4 columns]

# %%
df_ISOT_true
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 21412    August 22, 2017
# 21413    August 22, 2017
# 21414    August 22, 2017
# 21415    August 22, 2017
# 21416    August 22, 2017
#
# [21417 rows x 4 columns]

# %%
df_ISOT_true['label'] = 0
df_ISOT_false['label'] = 1
df_ISOT_true.drop(['subject', 'date'], axis=1, inplace=True)
df_ISOT_false.drop(['subject', 'date'], axis=1, inplace=True)

# %% [markdown]
# ### Data Description
#
# ISOT - focused mostly on collecting articles from 2016 to 2017. https://www.uvic.ca/engineering/ece/isot/datasets/fake-news/index.php <br>
# Kaggle - https://www.kaggle.com/c/fake-news/overview <br>
# Dataflair - https://data-flair.training/blogs/advanced-python-project-detecting-fake-news/

# %%
dfList = [df_ISOT_true, df_ISOT_false, df_DataFlair, df_KaggleTrain]
df_MAIN = pd.concat(dfList)
df_MAIN
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799                          What Keeps the F-35 Alive
#
#                                                     text label
# 0      WASHINGTON (Reuters) - The head of a conservat...     0
# 1      WASHINGTON (Reuters) - Transgender people will...     0
# 2      WASHINGTON (Reuters) - The special counsel inv...     0
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...     0
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...     0
# ...                                                  ...   ...
# 20795  Rapper T. I. unloaded on black celebrities who...     0
# 20796  When the Green Bay Packers lost to the Washing...     0
# 20797  The Macy’s of today grew from the union of sev...     0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...     1
# 20799    David Swanson is an author, activist, journa...     1
#
# [72033 rows x 3 columns]

# %%
df_MAIN['label'].value_counts()
# Out:
# 1       33894
# 0       31804
# REAL     3171
# FAKE     3164
# Name: label, dtype: int64

# %%
#0 = True
#1 = False

conditions = [
    df_MAIN['label'] == 1, 
    df_MAIN['label'] == 0,
    df_MAIN['label'] == 'REAL',
    df_MAIN['label'] == 'FAKE'
]

choices = [
    1, 
    0, 
    0,
    1
]

df_MAIN['label'] = np.select(conditions, choices, default='NA')
df_MAIN['label'].value_counts()
# Out:
# 1    37058
# 0    34975
# Name: label, dtype: int64

# %%
df = df_MAIN
df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799                          What Keeps the F-35 Alive
#
#                                                     text label
# 0      WASHINGTON (Reuters) - The head of a conservat...     0
# 1      WASHINGTON (Reuters) - Transgender people will...     0
# 2      WASHINGTON (Reuters) - The special counsel inv...     0
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...     0
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...     0
# ...                                                  ...   ...
# 20795  Rapper T. I. unloaded on black celebrities who...     0
# 20796  When the Green Bay Packers lost to the Washing...     0
# 20797  The Macy’s of today grew from the union of sev...     0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...     1
# 20799    David Swanson is an author, activist, journa...     1
#
# [72033 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72033 entries, 0 to 20799
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   71475 non-null  object
#  1   text    71994 non-null  object
#  2   label   72033 non-null  object
# dtypes: object(3)
# memory usage: 2.2+ MB

# %%
df.fillna('N/A', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72033 entries, 0 to 20799
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   72033 non-null  object
#  1   text    72033 non-null  object
#  2   label   72033 non-null  object
# dtypes: object(3)
# memory usage: 2.2+ MB

# %%
df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799                          What Keeps the F-35 Alive
#
#                                                     text label
# 0      WASHINGTON (Reuters) - The head of a conservat...     0
# 1      WASHINGTON (Reuters) - Transgender people will...     0
# 2      WASHINGTON (Reuters) - The special counsel inv...     0
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...     0
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...     0
# ...                                                  ...   ...
# 20795  Rapper T. I. unloaded on black celebrities who...     0
# 20796  When the Green Bay Packers lost to the Washing...     0
# 20797  The Macy’s of today grew from the union of sev...     0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...     1
# 20799    David Swanson is an author, activist, journa...     1
#
# [72033 rows x 3 columns]

# %%
def clean_text(text):
    # remove numbers
    text_nonum = re.sub(r'\d+', '', text)
    # remove punctuations and convert characters to lower case
    text_nopunct = "".join([char.lower() for char in text_nonum if char not in string.punctuation]) 
    # substitute multiple whitespace with single whitespace
    # Also, removes leading and trailing whitespaces
    text_no_doublespace = re.sub('\s+', ' ', text_nopunct).strip()
    return nltk.word_tokenize(text_no_doublespace)

df['text_cleaned'] = df['text'].apply(clean_text)
df

# %%
#removing stopwords
df['text'].apply(lambda x: [item for item in x if item not in stopwords.words('english')])
df
